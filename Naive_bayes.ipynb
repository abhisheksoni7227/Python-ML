# %%
from sklearn import datasets
wine = datasets.load_wine()

# %%
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
wine.data[0:2]
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, 1.560e+01, 1.270e+02, 2.800e+00,
#         3.060e+00, 2.800e-01, 2.290e+00, 5.640e+00, 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, 1.120e+01, 1.000e+02, 2.650e+00,
#         2.760e+00, 2.600e-01, 1.280e+00, 4.380e+00, 1.050e+00, 3.400e+00,
#         1.050e+03]])

# %%
wine.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
wine.target[0:2]
# Out:
# array([0, 0])

# %%
import pandas as pd
df = pd.DataFrame(wine.data,columns=wine.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df['target'] = wine.target
df[50:70]
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 50    13.05        1.73  2.04               12.4       92.0           2.72
# 51    13.83        1.65  2.60               17.2       94.0           2.45
# 52    13.82        1.75  2.42               14.0      111.0           3.88
# 53    13.77        1.90  2.68               17.1      115.0           3.00
# 54    13.74        1.67  2.25               16.4      118.0           2.60
# 55    13.56        1.73  2.46               20.5      116.0           2.96
# 56    14.22        1.70  2.30               16.3      118.0           3.20
# 57    13.29        1.97  2.68               16.8      102.0           3.00
# 58    13.72        1.43  2.50               16.7      108.0           3.40
# 59    12.37        0.94  1.36               10.6       88.0           1.98
# 60    12.33        1.10  2.28               16.0      101.0           2.05
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.3, random_state=100)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
clf = MultinomialNB()
from sklearn.metrics import ConfusionMatrixDisplay , classification_report

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test , y_test ,labels=clf.class_prior, cmap='magma'
)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
mn = MultinomialNB()
mn.fit(X_train,y_train)
mn.score(X_test,y_test)
# Out:
# 0.7777777777777778

# %% [markdown]
# ## Summary:
# ##### 1. Loaded dataset and applied preprocessing steps to clean the data.
# ##### 2. Trained and tested a Naive Bayes classifier on the processed data.
# ##### 3. Evaluated model performance using accuracy and confusion matrix.
